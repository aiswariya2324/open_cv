# %%
# !git clone https://github.com/SkalskiP/yolov9.git
# %cd yolov9
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 325, done.
# remote: Counting objects: 100% (216/216), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 325 (delta 158), reused 155 (delta 155), pack-reused 109
# Receiving objects: 100% (325/325), 2.23 MiB | 6.59 MiB/s, done.
# Resolving deltas: 100% (165/165), done.
# /content/yolov9
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 3.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 10.8 MB/s eta 0:00:00

# %%
HOME= "/content"
# !nvidia-smi
# Out:
# Mon May 13 12:25:12 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install -q roboflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.4 MB/s eta 0:00:00

# %%
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt

# %%
# !ls -la {HOME}/weights
# Out:
# total 804884
# drwxr-xr-x 2 root root      4096 May 11 10:01 .
# drwxr-xr-x 1 root root      4096 May 11 09:05 ..
# -rw-r--r-- 1 root root  51508261 Feb 18 12:36 gelan-c.pt
# -rw-r--r-- 1 root root  51508261 Feb 18 12:36 gelan-c.pt.1
# -rw-r--r-- 1 root root 117203713 Feb 18 12:36 gelan-e.pt
# -rw-r--r-- 1 root root 117203713 Feb 18 12:36 gelan-e.pt.1
# -rw-r--r-- 1 root root 103153312 Feb 18 12:36 yolov9-c.pt
# -rw-r--r-- 1 root root 103153312 Feb 18 12:36 yolov9-c.pt.1
# -rw-r--r-- 1 root root 140217688 Feb 18 12:36 yolov9-e.pt
# -rw-r--r-- 1 root root 140217688 Feb 18 12:36 yolov9-e.pt.1

# %%
SOURCE_IMAGE_PATH = f"{HOME}//content/skyline.jpg"

# %%
ls
# Out:
# benchmarks.py  export.py   panoptic/         segment/         utils/
# classify/      figure/     README.md         train_dual.py    val_dual.py
# data/          hubconf.py  requirements.txt  train.py         val.py
# detect.py      models/     scripts/          train_triple.py  val_triple.py

# %%
# !python detect.py --weights /content/weights/gelan-c.pt --source /content/skyline.jpg --conf 0.25  --save-c
# Out:
# usage: detect.py [-h] [--weights WEIGHTS [WEIGHTS ...]] [--source SOURCE] [--data DATA]
#                  [--imgsz IMGSZ [IMGSZ ...]] [--conf-thres CONF_THRES] [--iou-thres IOU_THRES]
#                  [--max-det MAX_DET] [--device DEVICE] [--view-img] [--save-txt] [--save-conf]
#                  [--save-crop] [--nosave] [--classes CLASSES [CLASSES ...]] [--agnostic-nms]
#                  [--augment] [--visualize] [--update] [--project PROJECT] [--name NAME]
#                  [--exist-ok] [--line-thickness LINE_THICKNESS] [--hide-labels] [--hide-conf]
#                  [--half] [--dnn] [--vid-stride VID_STRIDE]
# detect.py: error: ambiguous option: --save-c could match --save-conf, --save-crop

# %%
# !python detect.py --weights /content/weights/yolov9-c.pt --source /content/skyline.jpg --conf 0.25 --save-txt --save-conf
# Out:
# detect: weights=['/content/weights/yolov9-c.pt'], source=/content/skyline.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.2.1+cu121 CPU
#
# Fusing layers...
# Model summary: 724 layers, 51141120 parameters, 0 gradients, 238.7 GFLOPs
# Traceback (most recent call last):
#   File "/content/yolov9/detect.py", line 232, in <module>
#     main(opt)
#   File "/content/yolov9/detect.py", line 227, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
# ...

# %%
from IPython.display import Image
Image(filename=f"/content/skyline.jpg",width=600)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-2f902d48cd13> in <cell line: 2>()
#       1 from IPython.display import Image
# ----> 2 Image(filename=f"/content/skyline.jpg",width=600)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# ...

# %%
! pip install openimages

# %%
from openimages.download import download_dataset
download_dataset("./data", ["Hammer", "Scissors"],limit=50, annotation_format="pascal")
# Out:
# ...
# 100%|██████████| 50/50 [00:00<00:00, 1511.33it/s]
# {'hammer': {'images_dir': './data/hammer/images',
#   'annotations_dir': './data/hammer/pascal'},
#  'scissors': {'images_dir': './data/scissors/images',
#   'annotations_dir': './data/scissors/pascal'}}

# %%
import shutil
# Zip the folder
shutil.make_archive('/content/yolov9/data/hammer', 'zip', '/content/yolov9/data/hammer')
# Move the zip file to the root directory
shutil.move('/content/yolov9/data/hammer','/content')
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-33-132adeb593a1> in <cell line: 5>()
#       3 shutil.make_archive('/content/yolov9/data/hammer', 'zip', '/content/yolov9/data/hammer')
#       4 # Move the zip file to the root directory
# ----> 5 shutil.move('/content/yolov9/data/hammer','/content')
#
# /usr/lib/python3.10/shutil.py in move(src, dst, copy_function)
#     812
#     813         if os.path.exists(real_dst):
# --> 814             raise Error("Destination path '%s' already exists" % real_dst)
#     815     try:
#     816         os.rename(src, real_dst)
#
# Error: Destination path '/content/hammer' already exists

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="SD6UNr0lbc5Yb1m8vwRX")
project = rf.workspace("lalalalala-lpk9e").project("lallalaa")
version = project.version(1)
dataset = version.download("yolov9")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to lallalaa-1 in yolov9:: 100%|██████████| 1532/1532 [00:00<00:00, 6035.64it/s]

# %%
# %cd {HOME}/yolov9

# !python train_dual.py \
--batch 16 --epochs 25 --img 50 --min-items 0 --close-mosaic 15 \
--data /content/yolov9/lallalaa \
--weights /content/yolov9/models/detect/yolov9-c.yaml \
--cfg /content/yolov9/models/detect/yolov9-c.yaml \
--hyp hyp.scratch-high.yaml
# Out:
# /content/yolov9
# 2024-05-11 10:59:25.468888: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-11 10:59:25.468967: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-11 10:59:25.470312: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-11 10:59:26.744706: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# !python train_dual.py \
--batch 16 --epochs 25 --img 50 --min-items 0 --close-mosaic 15 \
--data /content/yolov9/lallalaa \
--weights /content/weights/yolov9-c.pt \
--cfg /content/yolov9/models/detect/yolov9-c.yaml \
--hyp hyp.scratch-high.yaml
# Out:
# 2024-05-11 11:02:30.483211: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-11 11:02:30.483304: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-11 11:02:30.485133: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-11 11:02:31.730855: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
